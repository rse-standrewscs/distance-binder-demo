# %% [markdown]
# # Getting Started with dssd
#
# ## Distance sampling survey design.

# %% [markdown]
# Based on https://examples.distancesampling.org/dssd-getting-started/GettingStarted-distill.html by Laura Marshall

# %%
library(dssd)
# Out:
# Warning message in fun(libname, pkgname):
# “no display name and no $DISPLAY environment variable”

# %% [markdown]
# ### Setting up the Region

# %%
shapefile.name <- system.file("extdata", "TrackExample.shp", package = "dssd")

# %%
region <- make.region(region.name = "study area",
                      shape = shapefile.name)

# %%
plot(region)
# Out:
# Plot with title “study area”

# %% [markdown]
# ### Creating a Coverage Grid

# %%
cover <- make.coverage(region,
                       n.grid.points = 1000)

# %% [markdown]
# ### Defining the Design

# %%
design <- make.design(region = region, 
                      design = "systematic",
                      line.length = 1300,
                      edge.protocol = "minus",
                      design.angle = 0,
                      truncation = 2,
                      coverage.grid = cover)

# %% [markdown]
# ### Generating a Survey

# %%
transects <- generate.transects(design)

# %%
transects
# Out:
#    Strata study area:
#    ___________________
# Design:  systematically spaced parallel transects
# Spacing:  9.258935
# Line length: 1303.792
# Trackline length: 1493.794
# Cyclic trackline length: 1685.656
# Number of samplers:  21
# Design angle:  0
# Edge protocol:  minus
# Covered area:  5151.565
# Strata coverage: 42.8%
# Strata area:  12036.62
#
#    Study Area Totals:
#    _________________
# Line length: 1303.792
# Trackline length: 1493.794
# Cyclic trackline length: 1685.656
# Number of samplers:  21
# Covered area:  5151.565
# Average coverage: 42.8%

# %%
plot(region, transects)
# Out:
# Plot with title “study area”

# %%
plot(region, transects, covered.area = TRUE)
# Out:
# Plot with title “study area”
